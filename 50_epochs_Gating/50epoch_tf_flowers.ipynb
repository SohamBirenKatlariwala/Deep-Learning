# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50, EfficientNetB0, resnet50, efficientnet
from tensorflow.keras.optimizers import Adam

# ---------------------------------------------------
# 1. Load the TF-Flowers Dataset
# ---------------------------------------------------
# Create train/validation split
(dataset_train, dataset_test), info = tfds.load(
    'tf_flowers',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True
)

# Number of classes in TF-Flowers
num_classes = info.features['label'].num_classes

# ---------------------------------------------------
# 2. Preprocess Data for ResNet and EfficientNet
# ---------------------------------------------------
IMG_SIZE = 224
batch_size = 32
AUTOTUNE = tf.data.AUTOTUNE

def preprocess_resnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = resnet50.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

def preprocess_efficientnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = efficientnet.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

# Create tf.data pipelines
train_ds_resnet = (dataset_train
                   .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                   .batch(batch_size)
                   .prefetch(AUTOTUNE))

test_ds_resnet = (dataset_test
                  .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                  .batch(batch_size)
                  .prefetch(AUTOTUNE))

train_ds_eff = (dataset_train
                .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
                .batch(batch_size)
                .prefetch(AUTOTUNE))

test_ds_eff = (dataset_test
               .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
               .batch(batch_size)
               .prefetch(AUTOTUNE))

# ---------------------------------------------------
# 3. Define Dynamic Channel Gate Layer
# ---------------------------------------------------
class DynamicChannelGate(tf.keras.layers.Layer):
    def __init__(self, num_channels, name=None):
        super().__init__(name=name)
        self.gate_params = tf.Variable(
            initial_value=tf.ones((num_channels,), dtype=tf.float32),
            trainable=True,
            name="gate_params"
        )

    def call(self, inputs, training=None):
        gate = tf.sigmoid(self.gate_params)
        gate = tf.reshape(gate, (1, 1, 1, -1))
        return inputs * gate

# ---------------------------------------------------
# 4. Define ResNet50 Model with Dynamic Gating
# ---------------------------------------------------
def create_resnet_dynamic_gating(input_shape, num_classes):
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    num_channels = x.shape[-1]
    gating_layer = DynamicChannelGate(num_channels=num_channels, name="dynamic_gating")
    x = gating_layer(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="ResNet_DynamicGating")
    return model

# ---------------------------------------------------
# 5. Define EfficientNetB0 Model with Dynamic Gating
# ---------------------------------------------------
def create_efficientnet_dynamic_gating(input_shape, num_classes):
    base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    num_channels = x.shape[-1]
    gating_layer = DynamicChannelGate(num_channels=num_channels, name="dynamic_gating")
    x = gating_layer(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="EfficientNet_DynamicGating")
    return model

# ---------------------------------------------------
# 6. Compile and Train the Models
# ---------------------------------------------------
# ResNet50 Model
resnet_model = create_resnet_dynamic_gating((IMG_SIZE, IMG_SIZE, 3), num_classes)
resnet_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning Dynamic-Gating ResNet50 on TF-Flowers ---")
history_resnet = resnet_model.fit(train_ds_resnet, epochs=50, validation_data=test_ds_resnet, verbose=1)

# EfficientNetB0 Model
eff_model = create_efficientnet_dynamic_gating((IMG_SIZE, IMG_SIZE, 3), num_classes)
eff_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning Dynamic-Gating EfficientNetB0 on TF-Flowers ---")
history_eff = eff_model.fit(train_ds_eff, epochs=50, validation_data=test_ds_eff, verbose=1)

# Evaluate ResNet50
loss_resnet, acc_resnet = resnet_model.evaluate(test_ds_resnet, verbose=0)
print(f"ResNet50 Final Accuracy: {acc_resnet:.4f}")

# Evaluate EfficientNetB0
loss_eff, acc_eff = eff_model.evaluate(test_ds_eff, verbose=0)
print(f"EfficientNetB0 Final Accuracy: {acc_eff:.4f}")
# Out:
# Downloading and preparing dataset 218.21 MiB (download: 218.21 MiB, generated: 221.83 MiB, total: 440.05 MiB) to /root/tensorflow_datasets/tf_flowers/3.0.1...
# Dl Completed...:   0%|          | 0/5 [00:00<?, ? file/s]
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.1. Subsequent calls will reuse this data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
#
# --- Fine-Tuning Dynamic-Gating ResNet50 on TF-Flowers ---
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 142s 738ms/step - accuracy: 0.7159 - loss: 0.7164 - val_accuracy: 0.8910 - val_loss: 0.4920
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 308ms/step - accuracy: 0.9791 - loss: 0.0809 - val_accuracy: 0.9455 - val_loss: 0.1574
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 314ms/step - accuracy: 0.9980 - loss: 0.0170 - val_accuracy: 0.9550 - val_loss: 0.1556
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9998 - loss: 0.0042 - val_accuracy: 0.9292 - val_loss: 0.2876
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 308ms/step - accuracy: 0.9979 - loss: 0.0111 - val_accuracy: 0.9523 - val_loss: 0.1561
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9605 - val_loss: 0.1439
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 307ms/step - accuracy: 1.0000 - loss: 6.1631e-04 - val_accuracy: 0.9605 - val_loss: 0.1454
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 313ms/step - accuracy: 1.0000 - loss: 4.2907e-04 - val_accuracy: 0.9632 - val_loss: 0.1488
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 44s 343ms/step - accuracy: 1.0000 - loss: 3.3918e-04 - val_accuracy: 0.9619 - val_loss: 0.1512
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 38s 314ms/step - accuracy: 1.0000 - loss: 2.6691e-04 - val_accuracy: 0.9632 - val_loss: 0.1515
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 308ms/step - accuracy: 1.0000 - loss: 2.0946e-04 - val_accuracy: 0.9646 - val_loss: 0.1542
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 309ms/step - accuracy: 1.0000 - loss: 1.7477e-04 - val_accuracy: 0.9646 - val_loss: 0.1562
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 309ms/step - accuracy: 1.0000 - loss: 1.3697e-04 - val_accuracy: 0.9632 - val_loss: 0.1573
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 320ms/step - accuracy: 1.0000 - loss: 1.3717e-04 - val_accuracy: 0.9646 - val_loss: 0.1589
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 308ms/step - accuracy: 1.0000 - loss: 1.1615e-04 - val_accuracy: 0.9605 - val_loss: 0.1604
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 306ms/step - accuracy: 1.0000 - loss: 1.0984e-04 - val_accuracy: 0.9605 - val_loss: 0.1611
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 315ms/step - accuracy: 1.0000 - loss: 8.7634e-05 - val_accuracy: 0.9605 - val_loss: 0.1631
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 308ms/step - accuracy: 1.0000 - loss: 8.0685e-05 - val_accuracy: 0.9619 - val_loss: 0.1646
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 313ms/step - accuracy: 1.0000 - loss: 7.0062e-05 - val_accuracy: 0.9605 - val_loss: 0.1653
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 1.0000 - loss: 6.4465e-05 - val_accuracy: 0.9605 - val_loss: 0.1662
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 314ms/step - accuracy: 1.0000 - loss: 5.7222e-05 - val_accuracy: 0.9591 - val_loss: 0.1680
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 308ms/step - accuracy: 1.0000 - loss: 5.4135e-05 - val_accuracy: 0.9591 - val_loss: 0.1691
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 314ms/step - accuracy: 1.0000 - loss: 5.1103e-05 - val_accuracy: 0.9591 - val_loss: 0.1705
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 317ms/step - accuracy: 1.0000 - loss: 4.5780e-05 - val_accuracy: 0.9591 - val_loss: 0.1721
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 312ms/step - accuracy: 1.0000 - loss: 4.3976e-05 - val_accuracy: 0.9591 - val_loss: 0.1732
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 310ms/step - accuracy: 1.0000 - loss: 3.6560e-05 - val_accuracy: 0.9591 - val_loss: 0.1745
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 306ms/step - accuracy: 1.0000 - loss: 3.4946e-05 - val_accuracy: 0.9591 - val_loss: 0.1753
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - accuracy: 1.0000 - loss: 3.2538e-05 - val_accuracy: 0.9591 - val_loss: 0.1762
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 309ms/step - accuracy: 1.0000 - loss: 3.0374e-05 - val_accuracy: 0.9591 - val_loss: 0.1776
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 32s 342ms/step - accuracy: 1.0000 - loss: 2.8475e-05 - val_accuracy: 0.9591 - val_loss: 0.1787
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 38s 314ms/step - accuracy: 1.0000 - loss: 2.5660e-05 - val_accuracy: 0.9591 - val_loss: 0.1799
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 314ms/step - accuracy: 1.0000 - loss: 2.3599e-05 - val_accuracy: 0.9591 - val_loss: 0.1807
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 307ms/step - accuracy: 1.0000 - loss: 2.2247e-05 - val_accuracy: 0.9591 - val_loss: 0.1816
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 315ms/step - accuracy: 1.0000 - loss: 2.0873e-05 - val_accuracy: 0.9591 - val_loss: 0.1825
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 43s 342ms/step - accuracy: 1.0000 - loss: 1.8267e-05 - val_accuracy: 0.9591 - val_loss: 0.1836
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 38s 313ms/step - accuracy: 1.0000 - loss: 1.8640e-05 - val_accuracy: 0.9591 - val_loss: 0.1844
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 308ms/step - accuracy: 1.0000 - loss: 1.8821e-05 - val_accuracy: 0.9591 - val_loss: 0.1858
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - accuracy: 1.0000 - loss: 1.6385e-05 - val_accuracy: 0.9591 - val_loss: 0.1865
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 314ms/step - accuracy: 1.0000 - loss: 1.4525e-05 - val_accuracy: 0.9591 - val_loss: 0.1866
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 320ms/step - accuracy: 1.0000 - loss: 1.4225e-05 - val_accuracy: 0.9591 - val_loss: 0.1878
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 315ms/step - accuracy: 1.0000 - loss: 1.5895e-05 - val_accuracy: 0.9591 - val_loss: 0.1893
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 308ms/step - accuracy: 1.0000 - loss: 1.3111e-05 - val_accuracy: 0.9591 - val_loss: 0.1899
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 306ms/step - accuracy: 1.0000 - loss: 1.1782e-05 - val_accuracy: 0.9591 - val_loss: 0.1908
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 314ms/step - accuracy: 1.0000 - loss: 1.1591e-05 - val_accuracy: 0.9591 - val_loss: 0.1914
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 315ms/step - accuracy: 1.0000 - loss: 1.1843e-05 - val_accuracy: 0.9591 - val_loss: 0.1920
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 32s 344ms/step - accuracy: 1.0000 - loss: 1.0754e-05 - val_accuracy: 0.9591 - val_loss: 0.1929
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 38s 312ms/step - accuracy: 1.0000 - loss: 8.9334e-06 - val_accuracy: 0.9591 - val_loss: 0.1943
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 310ms/step - accuracy: 1.0000 - loss: 9.8763e-06 - val_accuracy: 0.9591 - val_loss: 0.1951
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 313ms/step - accuracy: 1.0000 - loss: 8.5741e-06 - val_accuracy: 0.9591 - val_loss: 0.1965
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 315ms/step - accuracy: 1.0000 - loss: 7.3434e-06 - val_accuracy: 0.9591 - val_loss: 0.1974
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# --- Fine-Tuning Dynamic-Gating EfficientNetB0 on TF-Flowers ---
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 169s 853ms/step - accuracy: 0.5619 - loss: 1.2085 - val_accuracy: 0.9005 - val_loss: 0.2979
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 147ms/step - accuracy: 0.9133 - loss: 0.3272 - val_accuracy: 0.9441 - val_loss: 0.1849
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.9602 - loss: 0.1625 - val_accuracy: 0.9455 - val_loss: 0.1527
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9858 - loss: 0.0829 - val_accuracy: 0.9564 - val_loss: 0.1364
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 0.9963 - loss: 0.0393 - val_accuracy: 0.9578 - val_loss: 0.1355
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 142ms/step - accuracy: 0.9972 - loss: 0.0235 - val_accuracy: 0.9550 - val_loss: 0.1365
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 0.9978 - loss: 0.0167 - val_accuracy: 0.9591 - val_loss: 0.1387
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9986 - loss: 0.0114 - val_accuracy: 0.9550 - val_loss: 0.1359
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 142ms/step - accuracy: 0.9992 - loss: 0.0091 - val_accuracy: 0.9605 - val_loss: 0.1363
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - accuracy: 0.9998 - loss: 0.0060 - val_accuracy: 0.9564 - val_loss: 0.1391
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 147ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9591 - val_loss: 0.1441
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 148ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9578 - val_loss: 0.1449
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9605 - val_loss: 0.1476
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 149ms/step - accuracy: 0.9994 - loss: 0.0037 - val_accuracy: 0.9619 - val_loss: 0.1488
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9619 - val_loss: 0.1436
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 0.9995 - loss: 0.0032 - val_accuracy: 0.9659 - val_loss: 0.1421
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9993 - loss: 0.0043 - val_accuracy: 0.9605 - val_loss: 0.1585
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 144ms/step - accuracy: 0.9986 - loss: 0.0069 - val_accuracy: 0.9428 - val_loss: 0.1753
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9550 - val_loss: 0.1685
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9591 - val_loss: 0.1564
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9619 - val_loss: 0.1551
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 143ms/step - accuracy: 0.9996 - loss: 0.0031 - val_accuracy: 0.9646 - val_loss: 0.1489
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9646 - val_loss: 0.1472
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 144ms/step - accuracy: 0.9999 - loss: 0.0017 - val_accuracy: 0.9619 - val_loss: 0.1779
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 144ms/step - accuracy: 0.9998 - loss: 0.0021 - val_accuracy: 0.9673 - val_loss: 0.1626
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.9659 - val_loss: 0.1491
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 143ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9673 - val_loss: 0.1554
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 148ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9537 - val_loss: 0.1913
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9605 - val_loss: 0.1737
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 144ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9578 - val_loss: 0.1821
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9564 - val_loss: 0.2098
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 0.9990 - loss: 0.0021 - val_accuracy: 0.9564 - val_loss: 0.2131
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 1.0000 - loss: 7.3249e-04 - val_accuracy: 0.9564 - val_loss: 0.2115
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 1.0000 - loss: 5.1556e-04 - val_accuracy: 0.9578 - val_loss: 0.2181
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9591 - val_loss: 0.2230
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 148ms/step - accuracy: 1.0000 - loss: 6.7746e-04 - val_accuracy: 0.9619 - val_loss: 0.2111
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9591 - val_loss: 0.2043
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 149ms/step - accuracy: 1.0000 - loss: 7.2679e-04 - val_accuracy: 0.9591 - val_loss: 0.1943
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 0.9537 - val_loss: 0.1954
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9591 - val_loss: 0.1864
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.9967 - loss: 0.0096 - val_accuracy: 0.9632 - val_loss: 0.1828
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 144ms/step - accuracy: 0.9992 - loss: 0.0039 - val_accuracy: 0.9632 - val_loss: 0.1985
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 0.9591 - val_loss: 0.1773
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.9994 - loss: 0.0036 - val_accuracy: 0.9537 - val_loss: 0.1999
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 0.9980 - loss: 0.0070 - val_accuracy: 0.9578 - val_loss: 0.2033
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9968 - loss: 0.0091 - val_accuracy: 0.9537 - val_loss: 0.2181
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9482 - val_loss: 0.2139
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9496 - val_loss: 0.2038
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9523 - val_loss: 0.2115
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 151ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9510 - val_loss: 0.2377
# ResNet50 Final Accuracy: 0.9591
# EfficientNetB0 Final Accuracy: 0.9510
