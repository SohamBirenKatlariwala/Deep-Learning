# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50, EfficientNetB0, resnet50, efficientnet
from tensorflow.keras.optimizers import Adam
import numpy as np

# ---------------------------------------------------
# 1. Load the Caltech-101 Dataset
# ---------------------------------------------------
# Create train/test split
(dataset_train, dataset_test), info = tfds.load(
    'caltech101',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True
)

# Number of classes in Caltech-101
num_classes = info.features['label'].num_classes

# ---------------------------------------------------
# 2. Preprocess Data for ResNet and EfficientNet
# ---------------------------------------------------
IMG_SIZE = 224
batch_size = 32
AUTOTUNE = tf.data.AUTOTUNE

def preprocess_resnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = resnet50.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

def preprocess_efficientnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = efficientnet.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

# Create tf.data pipelines
train_ds_resnet = (dataset_train
                   .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                   .batch(batch_size)
                   .prefetch(AUTOTUNE))

val_ds_resnet = (dataset_test
                 .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                 .batch(batch_size)
                 .prefetch(AUTOTUNE))

train_ds_eff = (dataset_train
                .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
                .batch(batch_size)
                .prefetch(AUTOTUNE))

val_ds_eff = (dataset_test
              .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
              .batch(batch_size)
              .prefetch(AUTOTUNE))

# ---------------------------------------------------
# 3. Define Dynamic Channel Gate Layer
# ---------------------------------------------------
class DynamicChannelGate(tf.keras.layers.Layer):
    def __init__(self, num_channels, name=None):
        super().__init__(name=name)
        self.gate_params = tf.Variable(
            initial_value=tf.ones((num_channels,), dtype=tf.float32),
            trainable=True,
            name="gate_params"
        )

    def call(self, inputs, training=None):
        gate = tf.sigmoid(self.gate_params)
        gate = tf.reshape(gate, (1, 1, 1, -1))
        return inputs * gate

# ---------------------------------------------------
# 4. Define ResNet50 Model with Dynamic Gating
# ---------------------------------------------------
def create_resnet_dynamic_gating(input_shape, num_classes):
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    num_channels = x.shape[-1]
    gating_layer = DynamicChannelGate(num_channels=num_channels, name="dynamic_gating")
    x = gating_layer(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="ResNet_DynamicGating")
    return model

# ---------------------------------------------------
# 5. Define EfficientNetB0 Model with Dynamic Gating
# ---------------------------------------------------
def create_efficientnet_dynamic_gating(input_shape, num_classes):
    base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    num_channels = x.shape[-1]
    gating_layer = DynamicChannelGate(num_channels=num_channels, name="dynamic_gating")
    x = gating_layer(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="EfficientNet_DynamicGating")
    return model

# ---------------------------------------------------
# 6. Compile and Train the Models
# ---------------------------------------------------
# ResNet50 Model
resnet_model = create_resnet_dynamic_gating((IMG_SIZE, IMG_SIZE, 3), num_classes)
resnet_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning Dynamic-Gating ResNet50 on Caltech-101 ---")
history_resnet = resnet_model.fit(train_ds_resnet, epochs=50, validation_data=val_ds_resnet, verbose=1)

# EfficientNetB0 Model
eff_model = create_efficientnet_dynamic_gating((IMG_SIZE, IMG_SIZE, 3), num_classes)
eff_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning Dynamic-Gating EfficientNetB0 on Caltech-101 ---")
history_eff = eff_model.fit(train_ds_eff, epochs=50, validation_data=val_ds_eff, verbose=1)

# Evaluate ResNet50
loss_resnet, acc_resnet = resnet_model.evaluate(val_ds_resnet, verbose=0)
print(f"ResNet50 Final Accuracy: {acc_resnet:.4f}")

# Evaluate EfficientNetB0
loss_eff, acc_eff = eff_model.evaluate(val_ds_eff, verbose=0)
print(f"EfficientNetB0 Final Accuracy: {acc_eff:.4f}")
# Out:
# Downloading and preparing dataset 131.05 MiB (download: 131.05 MiB, generated: 132.86 MiB, total: 263.91 MiB) to /root/tensorflow_datasets/caltech101/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/3060 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/caltech101/incomplete.ZM79VG_3.0.2/caltech101-train.tfrecord*...:   0%|   …
# Generating test examples...:   0%|          | 0/6084 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/caltech101/incomplete.ZM79VG_3.0.2/caltech101-test.tfrecord*...:   0%|    …
# Dataset caltech101 downloaded and prepared to /root/tensorflow_datasets/caltech101/3.0.2. Subsequent calls will reuse this data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# --- Fine-Tuning Dynamic-Gating ResNet50 on Caltech-101 ---
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 154s 833ms/step - accuracy: 0.1981 - loss: 3.9724 - val_accuracy: 0.7582 - val_loss: 0.9957
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 63s 318ms/step - accuracy: 0.9496 - loss: 0.5618 - val_accuracy: 0.8971 - val_loss: 0.4692
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 317ms/step - accuracy: 0.9987 - loss: 0.0895 - val_accuracy: 0.9036 - val_loss: 0.4052
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 327ms/step - accuracy: 0.9994 - loss: 0.0264 - val_accuracy: 0.9118 - val_loss: 0.4169
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 321ms/step - accuracy: 0.9998 - loss: 0.0147 - val_accuracy: 0.9052 - val_loss: 0.4540
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9118 - val_loss: 0.4060
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 314ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9134 - val_loss: 0.3960
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 313ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9150 - val_loss: 0.3934
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 311ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9183 - val_loss: 0.3892
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9167 - val_loss: 0.3847
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 310ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9150 - val_loss: 0.3860
# Epoch 12/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 310ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9150 - val_loss: 0.3830
# Epoch 13/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 329ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9167 - val_loss: 0.3795
# Epoch 14/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9134 - val_loss: 0.3805
# Epoch 15/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9134 - val_loss: 0.3806
# Epoch 16/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 316ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9134 - val_loss: 0.3800
# Epoch 17/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 322ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9150 - val_loss: 0.3781
# Epoch 18/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 332ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9134 - val_loss: 0.3778
# Epoch 19/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 319ms/step - accuracy: 1.0000 - loss: 9.5071e-04 - val_accuracy: 0.9150 - val_loss: 0.3764
# Epoch 20/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 330ms/step - accuracy: 1.0000 - loss: 8.2500e-04 - val_accuracy: 0.9134 - val_loss: 0.3784
# Epoch 21/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 322ms/step - accuracy: 1.0000 - loss: 8.0763e-04 - val_accuracy: 0.9134 - val_loss: 0.3803
# Epoch 22/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 311ms/step - accuracy: 1.0000 - loss: 6.9183e-04 - val_accuracy: 0.9150 - val_loss: 0.3799
# Epoch 23/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 319ms/step - accuracy: 1.0000 - loss: 6.9561e-04 - val_accuracy: 0.9134 - val_loss: 0.3783
# Epoch 24/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 319ms/step - accuracy: 1.0000 - loss: 5.9469e-04 - val_accuracy: 0.9134 - val_loss: 0.3778
# Epoch 25/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 320ms/step - accuracy: 1.0000 - loss: 5.8457e-04 - val_accuracy: 0.9134 - val_loss: 0.3771
# Epoch 26/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 310ms/step - accuracy: 1.0000 - loss: 5.3176e-04 - val_accuracy: 0.9167 - val_loss: 0.3768
# Epoch 27/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 311ms/step - accuracy: 1.0000 - loss: 4.6489e-04 - val_accuracy: 0.9150 - val_loss: 0.3780
# Epoch 28/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 324ms/step - accuracy: 1.0000 - loss: 4.4150e-04 - val_accuracy: 0.9150 - val_loss: 0.3772
# Epoch 29/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 311ms/step - accuracy: 1.0000 - loss: 3.9664e-04 - val_accuracy: 0.9150 - val_loss: 0.3770
# Epoch 30/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 331ms/step - accuracy: 1.0000 - loss: 3.8762e-04 - val_accuracy: 0.9150 - val_loss: 0.3798
# Epoch 31/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 313ms/step - accuracy: 1.0000 - loss: 3.4875e-04 - val_accuracy: 0.9150 - val_loss: 0.3787
# Epoch 32/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 308ms/step - accuracy: 1.0000 - loss: 3.2623e-04 - val_accuracy: 0.9150 - val_loss: 0.3796
# Epoch 33/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 324ms/step - accuracy: 1.0000 - loss: 2.9755e-04 - val_accuracy: 0.9167 - val_loss: 0.3778
# Epoch 34/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 325ms/step - accuracy: 1.0000 - loss: 2.9953e-04 - val_accuracy: 0.9150 - val_loss: 0.3775
# Epoch 35/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - accuracy: 1.0000 - loss: 2.6874e-04 - val_accuracy: 0.9150 - val_loss: 0.3780
# Epoch 36/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 312ms/step - accuracy: 1.0000 - loss: 2.5777e-04 - val_accuracy: 0.9134 - val_loss: 0.3785
# Epoch 37/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 324ms/step - accuracy: 1.0000 - loss: 2.4248e-04 - val_accuracy: 0.9134 - val_loss: 0.3787
# Epoch 38/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 320ms/step - accuracy: 1.0000 - loss: 2.2862e-04 - val_accuracy: 0.9150 - val_loss: 0.3826
# Epoch 39/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 320ms/step - accuracy: 1.0000 - loss: 2.0728e-04 - val_accuracy: 0.9150 - val_loss: 0.3807
# Epoch 40/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 324ms/step - accuracy: 1.0000 - loss: 2.0601e-04 - val_accuracy: 0.9150 - val_loss: 0.3824
# Epoch 41/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 315ms/step - accuracy: 1.0000 - loss: 1.8510e-04 - val_accuracy: 0.9167 - val_loss: 0.3814
# Epoch 42/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 327ms/step - accuracy: 1.0000 - loss: 1.8576e-04 - val_accuracy: 0.9150 - val_loss: 0.3812
# Epoch 43/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 318ms/step - accuracy: 1.0000 - loss: 1.6498e-04 - val_accuracy: 0.9150 - val_loss: 0.3811
# Epoch 44/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 310ms/step - accuracy: 1.0000 - loss: 1.6824e-04 - val_accuracy: 0.9150 - val_loss: 0.3825
# Epoch 45/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 310ms/step - accuracy: 1.0000 - loss: 1.5715e-04 - val_accuracy: 0.9150 - val_loss: 0.3819
# Epoch 46/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 1.0000 - loss: 1.4810e-04 - val_accuracy: 0.9150 - val_loss: 0.3820
# Epoch 47/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 310ms/step - accuracy: 1.0000 - loss: 1.3601e-04 - val_accuracy: 0.9150 - val_loss: 0.3833
# Epoch 48/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 310ms/step - accuracy: 1.0000 - loss: 1.2668e-04 - val_accuracy: 0.9150 - val_loss: 0.3847
# Epoch 49/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 313ms/step - accuracy: 1.0000 - loss: 1.2352e-04 - val_accuracy: 0.9150 - val_loss: 0.3848
# Epoch 50/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 1.0000 - loss: 1.1832e-04 - val_accuracy: 0.9167 - val_loss: 0.3853
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- Fine-Tuning Dynamic-Gating EfficientNetB0 on Caltech-101 ---
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 150s 871ms/step - accuracy: 0.0554 - loss: 4.5137 - val_accuracy: 0.4869 - val_loss: 3.7890
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.5782 - loss: 3.4437 - val_accuracy: 0.7255 - val_loss: 2.4047
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 145ms/step - accuracy: 0.8393 - loss: 2.2035 - val_accuracy: 0.8137 - val_loss: 1.3280
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - accuracy: 0.9049 - loss: 1.2273 - val_accuracy: 0.8611 - val_loss: 0.8362
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 0.9478 - loss: 0.6931 - val_accuracy: 0.8938 - val_loss: 0.6457
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 0.9753 - loss: 0.4237 - val_accuracy: 0.9118 - val_loss: 0.5370
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.9855 - loss: 0.2732 - val_accuracy: 0.9036 - val_loss: 0.4711
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.9929 - loss: 0.1851 - val_accuracy: 0.9134 - val_loss: 0.4186
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9976 - loss: 0.1316 - val_accuracy: 0.9199 - val_loss: 0.3836
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 0.9997 - loss: 0.0942 - val_accuracy: 0.9150 - val_loss: 0.3548
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 0.9992 - loss: 0.0747 - val_accuracy: 0.9118 - val_loss: 0.3400
# Epoch 12/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.9998 - loss: 0.0608 - val_accuracy: 0.9118 - val_loss: 0.3258
# Epoch 13/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 145ms/step - accuracy: 0.9990 - loss: 0.0474 - val_accuracy: 0.9118 - val_loss: 0.3174
# Epoch 14/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.9150 - val_loss: 0.3164
# Epoch 15/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 0.9998 - loss: 0.0332 - val_accuracy: 0.9150 - val_loss: 0.3146
# Epoch 16/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 0.9984 - loss: 0.0289 - val_accuracy: 0.9199 - val_loss: 0.3110
# Epoch 17/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.9199 - val_loss: 0.3095
# Epoch 18/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.9199 - val_loss: 0.3082
# Epoch 19/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.9150 - val_loss: 0.3039
# Epoch 20/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.9167 - val_loss: 0.3040
# Epoch 21/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 141ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.9150 - val_loss: 0.3034
# Epoch 22/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 143ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.9183 - val_loss: 0.2977
# Epoch 23/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9183 - val_loss: 0.3057
# Epoch 24/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9150 - val_loss: 0.3129
# Epoch 25/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9993 - loss: 0.0103 - val_accuracy: 0.9167 - val_loss: 0.3040
# Epoch 26/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9199 - val_loss: 0.3045
# Epoch 27/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9232 - val_loss: 0.2955
# Epoch 28/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.9999 - loss: 0.0092 - val_accuracy: 0.9199 - val_loss: 0.2953
# Epoch 29/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9183 - val_loss: 0.2964
# Epoch 30/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9183 - val_loss: 0.3020
# Epoch 31/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 0.9991 - loss: 0.0074 - val_accuracy: 0.9183 - val_loss: 0.3076
# Epoch 32/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9199 - val_loss: 0.3063
# Epoch 33/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9998 - loss: 0.0074 - val_accuracy: 0.9183 - val_loss: 0.3198
# Epoch 34/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 147ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9199 - val_loss: 0.3037
# Epoch 35/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9199 - val_loss: 0.3125
# Epoch 36/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9150 - val_loss: 0.3146
# Epoch 37/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9150 - val_loss: 0.3094
# Epoch 38/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9183 - val_loss: 0.3080
# Epoch 39/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 150ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9216 - val_loss: 0.3115
# Epoch 40/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9183 - val_loss: 0.3137
# Epoch 41/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 146ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9167 - val_loss: 0.3177
# Epoch 42/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9150 - val_loss: 0.3242
# Epoch 43/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9150 - val_loss: 0.3272
# Epoch 44/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 0.9995 - loss: 0.0034 - val_accuracy: 0.9101 - val_loss: 0.3238
# Epoch 45/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9134 - val_loss: 0.3233
# Epoch 46/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9995 - loss: 0.0032 - val_accuracy: 0.9150 - val_loss: 0.3229
# Epoch 47/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9199 - val_loss: 0.3132
# Epoch 48/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 142ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9183 - val_loss: 0.3170
# Epoch 49/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9993 - loss: 0.0032 - val_accuracy: 0.9183 - val_loss: 0.3294
# Epoch 50/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9134 - val_loss: 0.3269
# ResNet50 Final Accuracy: 0.9167
# EfficientNetB0 Final Accuracy: 0.9134
