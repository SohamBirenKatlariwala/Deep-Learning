# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50, EfficientNetB0, resnet50, efficientnet
from tensorflow.keras.optimizers import Adam

# ---------------------------------------------------
# 1. Load the TF-Flowers Dataset
# ---------------------------------------------------
# Create train/validation split
(dataset_train, dataset_test), info = tfds.load(
    'tf_flowers',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True
)

# Number of classes in TF-Flowers
num_classes = info.features['label'].num_classes

# ---------------------------------------------------
# 2. Preprocess Data for ResNet and EfficientNet
# ---------------------------------------------------
IMG_SIZE = 224
batch_size = 32
AUTOTUNE = tf.data.AUTOTUNE

def preprocess_resnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = resnet50.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

def preprocess_efficientnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = efficientnet.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

# Create tf.data pipelines
train_ds_resnet = (dataset_train
                   .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                   .batch(batch_size)
                   .prefetch(AUTOTUNE))

test_ds_resnet = (dataset_test
                  .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                  .batch(batch_size)
                  .prefetch(AUTOTUNE))

train_ds_eff = (dataset_train
                .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
                .batch(batch_size)
                .prefetch(AUTOTUNE))

test_ds_eff = (dataset_test
               .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
               .batch(batch_size)
               .prefetch(AUTOTUNE))

# ---------------------------------------------------
# 3. Define ResNet50 Model without Dynamic Gating
# ---------------------------------------------------
def create_resnet_model(input_shape, num_classes):
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="ResNet")
    return model

# ---------------------------------------------------
# 4. Define EfficientNetB0 Model without Dynamic Gating
# ---------------------------------------------------
def create_efficientnet_model(input_shape, num_classes):
    base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="EfficientNet")
    return model

# ---------------------------------------------------
# 5. Compile and Train the Models
# ---------------------------------------------------
# ResNet50 Model
resnet_model = create_resnet_model((IMG_SIZE, IMG_SIZE, 3), num_classes)
resnet_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning ResNet50 on TF-Flowers ---")
history_resnet = resnet_model.fit(train_ds_resnet, epochs=50, validation_data=test_ds_resnet, verbose=1)

# EfficientNetB0 Model
eff_model = create_efficientnet_model((IMG_SIZE, IMG_SIZE, 3), num_classes)
eff_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning EfficientNetB0 on TF-Flowers ---")
history_eff = eff_model.fit(train_ds_eff, epochs=50, validation_data=test_ds_eff, verbose=1)

# Evaluate ResNet50
loss_resnet, acc_resnet = resnet_model.evaluate(test_ds_resnet, verbose=0)
print(f"ResNet50 Final Accuracy: {acc_resnet:.4f}")

# Evaluate EfficientNetB0
loss_eff, acc_eff = eff_model.evaluate(test_ds_eff, verbose=0)
print(f"EfficientNetB0 Final Accuracy: {acc_eff:.4f}")
# Out:
# Downloading and preparing dataset 218.21 MiB (download: 218.21 MiB, generated: 221.83 MiB, total: 440.05 MiB) to /root/tensorflow_datasets/tf_flowers/3.0.1...
# Dl Completed...:   0%|          | 0/5 [00:00<?, ? file/s]
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.1. Subsequent calls will reuse this data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- Fine-Tuning ResNet50 on TF-Flowers ---
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 139s 699ms/step - accuracy: 0.7121 - loss: 0.7832 - val_accuracy: 0.8978 - val_loss: 0.4790
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 287ms/step - accuracy: 0.9710 - loss: 0.0925 - val_accuracy: 0.9428 - val_loss: 0.1968
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 289ms/step - accuracy: 0.9983 - loss: 0.0133 - val_accuracy: 0.9537 - val_loss: 0.1566
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 300ms/step - accuracy: 0.9997 - loss: 0.0026 - val_accuracy: 0.9591 - val_loss: 0.1520
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 300ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9591 - val_loss: 0.1567
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 304ms/step - accuracy: 1.0000 - loss: 7.0212e-04 - val_accuracy: 0.9591 - val_loss: 0.1584
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 314ms/step - accuracy: 1.0000 - loss: 5.5331e-04 - val_accuracy: 0.9591 - val_loss: 0.1602
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 312ms/step - accuracy: 1.0000 - loss: 3.1966e-04 - val_accuracy: 0.9591 - val_loss: 0.1623
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 301ms/step - accuracy: 1.0000 - loss: 2.6593e-04 - val_accuracy: 0.9605 - val_loss: 0.1638
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 310ms/step - accuracy: 1.0000 - loss: 2.0547e-04 - val_accuracy: 0.9605 - val_loss: 0.1642
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 310ms/step - accuracy: 1.0000 - loss: 1.9470e-04 - val_accuracy: 0.9591 - val_loss: 0.1667
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 306ms/step - accuracy: 1.0000 - loss: 1.5076e-04 - val_accuracy: 0.9591 - val_loss: 0.1696
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 1.0000 - loss: 1.2660e-04 - val_accuracy: 0.9591 - val_loss: 0.1704
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 305ms/step - accuracy: 1.0000 - loss: 1.2617e-04 - val_accuracy: 0.9591 - val_loss: 0.1721
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 307ms/step - accuracy: 1.0000 - loss: 9.7112e-05 - val_accuracy: 0.9591 - val_loss: 0.1740
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - accuracy: 1.0000 - loss: 9.7247e-05 - val_accuracy: 0.9591 - val_loss: 0.1746
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 41s 306ms/step - accuracy: 1.0000 - loss: 8.7207e-05 - val_accuracy: 0.9605 - val_loss: 0.1762
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 299ms/step - accuracy: 1.0000 - loss: 8.2142e-05 - val_accuracy: 0.9605 - val_loss: 0.1779
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 42s 311ms/step - accuracy: 1.0000 - loss: 6.6194e-05 - val_accuracy: 0.9605 - val_loss: 0.1794
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s
50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 145ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.9591 - val_loss: 0.1584
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 144ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9605 - val_loss: 0.1560
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9591 - val_loss: 0.1669
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9578 - val_loss: 0.1603
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 141ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9591 - val_loss: 0.1640
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 140ms/step - accuracy: 0.9987 - loss: 0.0078 - val_accuracy: 0.9523 - val_loss: 0.1870
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 142ms/step - accuracy: 0.9963 - loss: 0.0140 - val_accuracy: 0.9550 - val_loss: 0.1746
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9605 - val_loss: 0.1656
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 1.0000 - loss: 9.2843e-04 - val_accuracy: 0.9605 - val_loss: 0.1643
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9550 - val_loss: 0.1753
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 144ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9591 - val_loss: 0.1719
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9496 - val_loss: 0.1934
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.9537 - val_loss: 0.1868
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9523 - val_loss: 0.1865
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 140ms/step - accuracy: 1.0000 - loss: 7.4369e-04 - val_accuracy: 0.9523 - val_loss: 0.1785
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.9564 - val_loss: 0.1891
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9591 - val_loss: 0.1782
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 144ms/step - accuracy: 1.0000 - loss: 8.8783e-04 - val_accuracy: 0.9578 - val_loss: 0.1774
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 1.0000 - loss: 6.6036e-04 - val_accuracy: 0.9564 - val_loss: 0.1804
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 145ms/step - accuracy: 0.9999 - loss: 5.3051e-04 - val_accuracy: 0.9510 - val_loss: 0.1926
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 146ms/step - accuracy: 1.0000 - loss: 9.3223e-04 - val_accuracy: 0.9564 - val_loss: 0.1811
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 1.0000 - loss: 5.9799e-04 - val_accuracy: 0.9578 - val_loss: 0.1773
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 1.0000 - loss: 8.0413e-04 - val_accuracy: 0.9578 - val_loss: 0.1820
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 140ms/step - accuracy: 1.0000 - loss: 3.3596e-04 - val_accuracy: 0.9578 - val_loss: 0.1778
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9591 - val_loss: 0.1744
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 138ms/step - accuracy: 0.9999 - loss: 9.2452e-04 - val_accuracy: 0.9550 - val_loss: 0.1965
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 139ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9428 - val_loss: 0.2208
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 0.9983 - loss: 0.0041 - val_accuracy: 0.9428 - val_loss: 0.2286
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9510 - val_loss: 0.2125
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - accuracy: 0.9992 - loss: 0.0021 - val_accuracy: 0.9537 - val_loss: 0.1696
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 143ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9510 - val_loss: 0.1885
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9605 - val_loss: 0.1753
# ResNet50 Final Accuracy: 0.9578
# EfficientNetB0 Final Accuracy: 0.9605
