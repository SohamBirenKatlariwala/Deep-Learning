# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50, EfficientNetB0, resnet50, efficientnet
from tensorflow.keras.optimizers import Adam

# ---------------------------------------------------
# 1. Load the Caltech-101 Dataset
# ---------------------------------------------------
# Create train/validation split
(dataset_train, dataset_test), info = tfds.load(
    'caltech101',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True
)

# Number of classes in Caltech-101
num_classes = info.features['label'].num_classes

# ---------------------------------------------------
# 2. Preprocess Data for ResNet and EfficientNet
# ---------------------------------------------------
IMG_SIZE = 224
batch_size = 32
AUTOTUNE = tf.data.AUTOTUNE

def preprocess_resnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = resnet50.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

def preprocess_efficientnet(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = efficientnet.preprocess_input(image)
    return image, tf.one_hot(label, num_classes)

# Create tf.data pipelines
train_ds_resnet = (dataset_train
                   .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                   .batch(batch_size)
                   .prefetch(AUTOTUNE))

test_ds_resnet = (dataset_test
                  .map(preprocess_resnet, num_parallel_calls=AUTOTUNE)
                  .batch(batch_size)
                  .prefetch(AUTOTUNE))

train_ds_eff = (dataset_train
                .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
                .batch(batch_size)
                .prefetch(AUTOTUNE))

test_ds_eff = (dataset_test
               .map(preprocess_efficientnet, num_parallel_calls=AUTOTUNE)
               .batch(batch_size)
               .prefetch(AUTOTUNE))

# ---------------------------------------------------
# 3. Define ResNet50 Model without Dynamic Gating
# ---------------------------------------------------
def create_resnet_model(input_shape, num_classes):
    base_model = ResNet50(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="ResNet")
    return model

# ---------------------------------------------------
# 4. Define EfficientNetB0 Model without Dynamic Gating
# ---------------------------------------------------
def create_efficientnet_model(input_shape, num_classes):
    base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=input_shape)
    base_model.trainable = True

    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="EfficientNet")
    return model

# ---------------------------------------------------
# 5. Compile and Train the Models
# ---------------------------------------------------
# ResNet50 Model
resnet_model = create_resnet_model((IMG_SIZE, IMG_SIZE, 3), num_classes)
resnet_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning ResNet50 on Caltech-101 ---")
history_resnet = resnet_model.fit(train_ds_resnet, epochs=50, validation_data=test_ds_resnet, verbose=1)

# EfficientNetB0 Model
eff_model = create_efficientnet_model((IMG_SIZE, IMG_SIZE, 3), num_classes)
eff_model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("\n--- Fine-Tuning EfficientNetB0 on Caltech-101 ---")
history_eff = eff_model.fit(train_ds_eff, epochs=50, validation_data=test_ds_eff, verbose=1)

# Evaluate ResNet50
loss_resnet, acc_resnet = resnet_model.evaluate(test_ds_resnet, verbose=0)
print(f"ResNet50 Final Accuracy: {acc_resnet:.4f}")

# Evaluate EfficientNetB0
loss_eff, acc_eff = eff_model.evaluate(test_ds_eff, verbose=0)
print(f"EfficientNetB0 Final Accuracy: {acc_eff:.4f}")
# Out:
# Downloading and preparing dataset 131.05 MiB (download: 131.05 MiB, generated: 132.86 MiB, total: 263.91 MiB) to /root/tensorflow_datasets/caltech101/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/3060 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/caltech101/incomplete.ATYYSF_3.0.2/caltech101-train.tfrecord*...:   0%|   …
# Generating test examples...:   0%|          | 0/6084 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/caltech101/incomplete.ATYYSF_3.0.2/caltech101-test.tfrecord*...:   0%|    …
# Dataset caltech101 downloaded and prepared to /root/tensorflow_datasets/caltech101/3.0.2. Subsequent calls will reuse this data.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# --- Fine-Tuning ResNet50 on Caltech-101 ---
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 151s 808ms/step - accuracy: 0.1840 - loss: 4.1407 - val_accuracy: 0.7876 - val_loss: 0.8258
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 314ms/step - accuracy: 0.9548 - loss: 0.4024 - val_accuracy: 0.8824 - val_loss: 0.4775
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 307ms/step - accuracy: 0.9980 - loss: 0.0560 - val_accuracy: 0.8938 - val_loss: 0.4370
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 313ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.8954 - val_loss: 0.4368
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 307ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9020 - val_loss: 0.4240
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9003 - val_loss: 0.4360
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.8987 - val_loss: 0.4268
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 305ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9020 - val_loss: 0.4146
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9052 - val_loss: 0.4074
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 306ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9069 - val_loss: 0.4075
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 314ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9069 - val_loss: 0.4013
# Epoch 12/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 317ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9036 - val_loss: 0.4063
# Epoch 13/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 312ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9052 - val_loss: 0.4051
# Epoch 14/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9052 - val_loss: 0.4011
# Epoch 15/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 324ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9085 - val_loss: 0.4016
# Epoch 16/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9069 - val_loss: 0.4023
# Epoch 17/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 1.0000 - loss: 9.9454e-04 - val_accuracy: 0.9085 - val_loss: 0.4019
# Epoch 18/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 311ms/step - accuracy: 1.0000 - loss: 9.4292e-04 - val_accuracy: 0.9069 - val_loss: 0.4004
# Epoch 19/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 315ms/step - accuracy: 1.0000 - loss: 8.4329e-04 - val_accuracy: 0.9085 - val_loss: 0.3975
# Epoch 20/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 23s 304ms/step - accuracy: 1.0000 - loss: 7.1240e-04 - val_accuracy: 0.9085 - val_loss: 0.3965
# Epoch 21/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 1.0000 - loss: 6.9371e-04 - val_accuracy: 0.9085 - val_loss: 0.3973
# Epoch 22/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 320ms/step - accuracy: 1.0000 - loss: 6.5400e-04 - val_accuracy: 0.9085 - val_loss: 0.3982
# Epoch 23/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 320ms/step - accuracy: 1.0000 - loss: 5.8465e-04 - val_accuracy: 0.9052 - val_loss: 0.3975
# Epoch 24/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 307ms/step - accuracy: 1.0000 - loss: 5.4317e-04 - val_accuracy: 0.9069 - val_loss: 0.3972
# Epoch 25/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 329ms/step - accuracy: 1.0000 - loss: 4.8379e-04 - val_accuracy: 0.9101 - val_loss: 0.3950
# Epoch 26/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 308ms/step - accuracy: 1.0000 - loss: 4.5617e-04 - val_accuracy: 0.9052 - val_loss: 0.3966
# Epoch 27/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - accuracy: 1.0000 - loss: 4.4375e-04 - val_accuracy: 0.9036 - val_loss: 0.3979
# Epoch 28/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 311ms/step - accuracy: 1.0000 - loss: 3.7793e-04 - val_accuracy: 0.9052 - val_loss: 0.3965
# Epoch 29/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 1.0000 - loss: 3.4686e-04 - val_accuracy: 0.9052 - val_loss: 0.3977
# Epoch 30/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 316ms/step - accuracy: 1.0000 - loss: 3.2442e-04 - val_accuracy: 0.9069 - val_loss: 0.3998
# Epoch 31/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 310ms/step - accuracy: 1.0000 - loss: 2.9155e-04 - val_accuracy: 0.9052 - val_loss: 0.3982
# Epoch 32/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 309ms/step - accuracy: 1.0000 - loss: 3.0643e-04 - val_accuracy: 0.9069 - val_loss: 0.3969
# Epoch 33/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 321ms/step - accuracy: 1.0000 - loss: 3.1680e-04 - val_accuracy: 0.9101 - val_loss: 0.3964
# Epoch 34/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 322ms/step - accuracy: 1.0000 - loss: 2.6423e-04 - val_accuracy: 0.9085 - val_loss: 0.3972
# Epoch 35/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 304ms/step - accuracy: 1.0000 - loss: 2.6574e-04 - val_accuracy: 0.9101 - val_loss: 0.3956
# Epoch 36/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 305ms/step - accuracy: 1.0000 - loss: 2.1390e-04 - val_accuracy: 0.9069 - val_loss: 0.3970
# Epoch 37/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 1.0000 - loss: 2.1553e-04 - val_accuracy: 0.9085 - val_loss: 0.3962
# Epoch 38/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 320ms/step - accuracy: 1.0000 - loss: 2.0639e-04 - val_accuracy: 0.9085 - val_loss: 0.3955
# Epoch 39/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 321ms/step - accuracy: 1.0000 - loss: 1.9886e-04 - val_accuracy: 0.9085 - val_loss: 0.3966
# Epoch 40/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 316ms/step - accuracy: 1.0000 - loss: 1.6780e-04 - val_accuracy: 0.9085 - val_loss: 0.3934
# Epoch 41/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 1.0000 - loss: 1.6984e-04 - val_accuracy: 0.9085 - val_loss: 0.3954
# Epoch 42/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 306ms/step - accuracy: 1.0000 - loss: 1.4832e-04 - val_accuracy: 0.9085 - val_loss: 0.3959
# Epoch 43/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 330ms/step - accuracy: 1.0000 - loss: 1.3713e-04 - val_accuracy: 0.9069 - val_loss: 0.3966
# Epoch 44/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 313ms/step - accuracy: 1.0000 - loss: 1.4295e-04 - val_accuracy: 0.9069 - val_loss: 0.3964
# Epoch 45/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 314ms/step - accuracy: 1.0000 - loss: 1.2849e-04 - val_accuracy: 0.9069 - val_loss: 0.3965
# Epoch 46/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 309ms/step - accuracy: 1.0000 - loss: 1.2913e-04 - val_accuracy: 0.9069 - val_loss: 0.3964
# Epoch 47/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 313ms/step - accuracy: 1.0000 - loss: 1.1393e-04 - val_accuracy: 0.9085 - val_loss: 0.3973
# Epoch 48/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 321ms/step - accuracy: 1.0000 - loss: 1.1375e-04 - val_accuracy: 0.9085 - val_loss: 0.3963
# Epoch 49/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 40s 311ms/step - accuracy: 1.0000 - loss: 1.1226e-04 - val_accuracy: 0.9085 - val_loss: 0.3958
# Epoch 50/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 308ms/step - accuracy: 1.0000 - loss: 9.7002e-05 - val_accuracy: 0.9069 - val_loss: 0.3960
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- Fine-Tuning EfficientNetB0 on Caltech-101 ---
# Epoch 1/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 150s 871ms/step - accuracy: 0.0445 - loss: 4.5202 - val_accuracy: 0.5458 - val_loss: 3.4885
# Epoch 2/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 144ms/step - accuracy: 0.6213 - loss: 3.1168 - val_accuracy: 0.8088 - val_loss: 1.8604
# Epoch 3/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 144ms/step - accuracy: 0.8658 - loss: 1.6893 - val_accuracy: 0.8644 - val_loss: 0.9279
# Epoch 4/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.9346 - loss: 0.8398 - val_accuracy: 0.8954 - val_loss: 0.6311
# Epoch 5/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9658 - loss: 0.4463 - val_accuracy: 0.9085 - val_loss: 0.5134
# Epoch 6/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.9823 - loss: 0.2784 - val_accuracy: 0.9118 - val_loss: 0.4458
# Epoch 7/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - accuracy: 0.9944 - loss: 0.1822 - val_accuracy: 0.9167 - val_loss: 0.4054
# Epoch 8/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 150ms/step - accuracy: 0.9967 - loss: 0.1176 - val_accuracy: 0.9134 - val_loss: 0.3779
# Epoch 9/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - accuracy: 0.9978 - loss: 0.0906 - val_accuracy: 0.9216 - val_loss: 0.3500
# Epoch 10/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.9983 - loss: 0.0671 - val_accuracy: 0.9265 - val_loss: 0.3417
# Epoch 11/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 0.9979 - loss: 0.0544 - val_accuracy: 0.9232 - val_loss: 0.3285
# Epoch 12/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 0.9997 - loss: 0.0434 - val_accuracy: 0.9232 - val_loss: 0.3222
# Epoch 13/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 144ms/step - accuracy: 0.9994 - loss: 0.0339 - val_accuracy: 0.9232 - val_loss: 0.3235
# Epoch 14/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 0.9183 - val_loss: 0.3162
# Epoch 15/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.9167 - val_loss: 0.3136
# Epoch 16/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 139ms/step - accuracy: 0.9997 - loss: 0.0227 - val_accuracy: 0.9248 - val_loss: 0.3062
# Epoch 17/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.9232 - val_loss: 0.3082
# Epoch 18/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.9248 - val_loss: 0.2985
# Epoch 19/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.9216 - val_loss: 0.2990
# Epoch 20/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.9998 - loss: 0.0124 - val_accuracy: 0.9314 - val_loss: 0.2883
# Epoch 21/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.9265 - val_loss: 0.2927
# Epoch 22/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.9248 - val_loss: 0.3001
# Epoch 23/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 0.9999 - loss: 0.0107 - val_accuracy: 0.9297 - val_loss: 0.2967
# Epoch 24/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9314 - val_loss: 0.2926
# Epoch 25/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.9998 - loss: 0.0090 - val_accuracy: 0.9330 - val_loss: 0.2898
# Epoch 26/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9314 - val_loss: 0.2970
# Epoch 27/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9297 - val_loss: 0.2968
# Epoch 28/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9248 - val_loss: 0.2975
# Epoch 29/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9265 - val_loss: 0.2917
# Epoch 30/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9248 - val_loss: 0.2879
# Epoch 31/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9232 - val_loss: 0.2915
# Epoch 32/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9265 - val_loss: 0.2967
# Epoch 33/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9232 - val_loss: 0.2957
# Epoch 34/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9248 - val_loss: 0.2965
# Epoch 35/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 140ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9265 - val_loss: 0.2968
# Epoch 36/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9297 - val_loss: 0.3046
# Epoch 37/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9232 - val_loss: 0.2815
# Epoch 38/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9248 - val_loss: 0.2963
# Epoch 39/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9248 - val_loss: 0.3099
# Epoch 40/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9265 - val_loss: 0.3019
# Epoch 41/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9248 - val_loss: 0.3028
# Epoch 42/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 139ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9281 - val_loss: 0.2836
# Epoch 43/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 140ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9314 - val_loss: 0.3042
# Epoch 44/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9314 - val_loss: 0.3000
# Epoch 45/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9297 - val_loss: 0.3054
# Epoch 46/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9248 - val_loss: 0.3069
# Epoch 47/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9297 - val_loss: 0.3051
# Epoch 48/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 138ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9281 - val_loss: 0.3028
# Epoch 49/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 148ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9248 - val_loss: 0.3101
# Epoch 50/50
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9248 - val_loss: 0.3302
# ResNet50 Final Accuracy: 0.9069
# EfficientNetB0 Final Accuracy: 0.9248
